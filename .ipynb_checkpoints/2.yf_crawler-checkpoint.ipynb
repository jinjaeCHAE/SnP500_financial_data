# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import numpy as np

# %%
import time

# %%
def make_ticker_rate_df(tickers):
    driver = webdriver.Chrome('./chromedriver')
    ticker_list = list()
    ann_growth_rate_list = list()
    year_list = list()
    recent_year = list()
    total_rev_ttm = list()
    check_number = 0
    for ticker in tickers:
        
        check_number += 1
        print(ticker + ', ' +str(check_number) + '번째 수행 중')
        driver.get('https://finance.yahoo.com/quote/' + ticker + '/financials?p=' + ticker)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        years = list()
        revenues = list()
        for i in range(36,76,2):
            data = soup.find_all(['span'],attrs={'data-reactid':i})
            if data:
                if 36 <= i < 58:
                    for i in range(len(data)):
                        if data[i].get_text()[-4:-2] == '20' and data[i].get_text()[-1].isdigit():
                            years.append(data[i].get_text()[-4:])
                            break
                else:
                    data = data[0].get_text()
                    if data and not data[0].isalpha():
                        data = data.replace(',','')
                        revenues.append(data)
                time.sleep(5)
        if revenues:
            ticker_list.append(ticker)
            ann_growth_rate_list.append(round(((int(revenues[1]) / int(revenues[-1])) ** (1.0/(len(years)-1)) - 1) * 100,2))
            year_list.append(len(years))
            recent_year.append(int(years[0]))
            total_rev_ttm.append(int(revenues[0]))
        else:
            ticker_list.append(ticker)
            ann_growth_rate_list.append(0)
            year_list.append(0)
            recent_year.append(0)
            total_rev_ttm.append(0)          
    print('크롤링 종료')
    driver.close()
    return pd.DataFrame({'ticker':ticker_list,'ann_growth_rate':ann_growth_rate_list,'total_rev_ttm':total_rev_ttm, 'num_of_year':year_list,'recent_year':recent_year})

# %%
tickers = ['GOOG','BABA','NFLX']
make_ticker_rate_df(tickers)
# Out:
# 1번째 수행 중
# GOOG
# ['166030000', '161857000', '136819000', '110855000']
# []
# 2번째 수행 중
# BABA
# ['584580000', '509711000', '376844000', '250266000', '158273000']
# [3]
# 3번째 수행 중
# NFLX
# ['24996056', '24996056', '20156447', '15794341', '11692713']
# [3, 4]
# 크롤링 종료
#   ticker  ann_growth_rate  total_rev_ttm  num_of_year  recent_year
# 0   GOOG            20.83      166030000            3         2019
# 1   BABA            47.67      584580000            4         2020
# 2   NFLX            28.82       24996056            4         2020

# %%
import FinanceDataReader as fdr

# %%
df_spx = fdr.StockListing('S&P500')
df_spx.head()
# Out:
#   Symbol                 Name                  Sector  \
# 0    MMM           3M Company             Industrials
# 1    ABT  Abbott Laboratories             Health Care
# 2   ABBV          AbbVie Inc.             Health Care
# 3   ABMD          ABIOMED Inc             Health Care
# 4    ACN        Accenture plc  Information Technology
#
#                          Industry
# 0        Industrial Conglomerates
# 1           Health Care Equipment
# 2                 Pharmaceuticals
# 3           Health Care Equipment
# 4  IT Consulting & Other Services

# %%
df_spx_ticker = list(df_spx.Symbol)
df_spx_ticker[:50]
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AMD',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ANET']

# %%
df = make_ticker_rate_df(df_spx_ticker)
# Out:
# 1번째 수행 중
# MMM
# ['32184000', '32184000', '32136000', '32765000', '31657000']
# ['2020', '2019', '2018', '2017']
# 2번째 수행 중
# ABT
# ['32221000', '31904000', '30578000', '27390000']
# ['2019', '2018', '2017']
# 3번째 수행 중
# ABBV
# ['34057000', '33266000', '32753000', '28216000']
# ['2019', '2018', '2017']
# 4번째 수행 중
# ABMD
# ['802857', '840883', '769432', '593749', '445304']
# ['2020', '2019', '2018', '2017']
# 5번째 수행 중
# ACN
# ['44730266', '44327039', '43215013', '41603428', '36765478']
# ['2020', '2019', '2018', '2017']
# 6번째 수행 중
# ATVI
# ['6452000', '6489000', '7500000', '7017000']
# ['2019', '2018', '2017']
# 7번째 수행 중
# ADBE
# ['12868000', '12868000', '11171297', '9030008', '7301505']
# ['2020', '2019', '2018', '2017']
# 8번째 수행 중
# AMD
# ['9763000', '9763000', '6731000', '6475000', '5329000']
# ['2020', '2019', '2018', '2017']
# 9번째 수행 중
# AAP
# ['9623982', '9709003', '9580554', '9373784']
# ['2019', '2018', '2017']
# 10번째 수행 중
# AES
# ['9531000', '10189000', '10736000', '10530000']
# ['2019', '2018', '2017']
# 11번째 수행 중
# AFL
# ['21682000', '22223000', '21689000', '21600000']
# ['2019', '2018', '2017']
# 12번째 수행 중
# A
# ['5339000', '5339000', '5163000', '4914000', '4472000']
# ['2020', '2019', '2018', '2017']
# 13번째 수행 중
# APD
# ['8856300', '8856300', '8918900', '8930200', '8187600']
# ['2020', '2019', '2018', '2017']
# 14번째 수행 중
# AKAM
# ['3123985', '2893617', '2714474', '2502996']
# ['2019', '2018', '2017']
# 15번째 수행 중
# ALK
# ['8781000', '3566000', '8781000', '8264000', '7933000']
# ['2020', '2019', '2018', '2017']
# 16번째 수행 중
# ALB
# ['3242326', '3589427', '3374950', '3071976']
# ['2019', '2018', '2017']
# 17번째 수행 중
# ARE
# ['1830031', '1531296', '1327459', '1124511']
# ['2019', '2018', '2017']
# 18번째 수행 중
# ALXN
# ['5862400', '4991100', '4131200', '3551100']
# ['2019', '2018', '2017']
# 19번째 수행 중
# ALGN
# ['2287208', '2406796', '1966492', '1473413']
# ['2019', '2018', '2017']
# 20번째 수행 중
# ALLE
# ['2712100', '2854000', '2731700', '2408200']
# ['2019', '2018', '2017']
# 21번째 수행 중
# LNT
# ['3478700', '3647700', '3534500', '3382200']
# ['2019', '2018', '2017']
# 22번째 수행 중
# ALL
# ['44675000', '44675000', '39815000', '38524000']
# ['2019', '2018', '2017']
# 23번째 수행 중
# GOOGL
# ['166030000', '161857000', '136819000', '110855000']
# ['2019', '2018', '2017']
# 24번째 수행 중
# GOOG
# ['166030000', '161857000', '136819000', '110855000']
# ['2019', '2018', '2017']
# 25번째 수행 중
# MO
# ['20588000', '19796000', '19627000', '19494000']
# ['2019', '2018', '2017']
# 26번째 수행 중
# AMZN
# ['321782000', '280522000', '232887000', '177866000']
# ['2019', '2018', '2017']
# 27번째 수행 중
# AMCR
# ['12423500', '12467500', '9458200', '9262259', '9092132']
# ['2020', '2019', '2018', '2017']
# 28번째 수행 중
# AEE
# ['6013000', '5910000', '6291000', '6177000']
# ['2019', '2018', '2017']
# 29번째 수행 중
# AAL
# ['24622000', '45768000', '44541000', '42207000']
# ['2019', '2018', '2017']
# 30번째 수행 중
# AEP
# ['14923900', '15561400', '16195700', '15424900']
# ['2019', '2018', '2017']
# 31번째 수행 중
# AXP
# ['26816000', '26816000', '30895000', '28865000', '24424000']
# ['2020', '2019', '2018', '2017']
# 32번째 수행 중
# AIG
# ['49792000', '49792000', '47481000', '49930000']
# ['2019', '2018', '2017']
# 33번째 수행 중
# AMT
# ['7783400', '7580300', '7440100', '6663900']
# ['2019', '2018', '2017']
# 34번째 수행 중
# AWK
# ['3610000', '3610000', '3440000', '3357000']
# ['2019', '2018', '2017']
# 35번째 수행 중
# AMP
# ['11873000', '12890000', '12924000', '12075000']
# ['2019', '2018', '2017']
# 36번째 수행 중
# ABC
# ['189893926', '189893926', '179589121', '167939635', '153143826']
# ['2020', '2019', '2018', '2017']
# 37번째 수행 중
# AME
# ['5073084', '5158557', '4845872', '4300170']
# ['2019', '2018', '2017']
# 38번째 수행 중
# AMGN
# ['24987000', '23362000', '23747000', '22849000']
# ['2019', '2018', '2017']
# 39번째 수행 중
# APH
# ['8323900', '8225400', '8202000', '7011300']
# ['2019', '2018', '2017']
# 40번째 수행 중
# ADI
# ['5603056', '5603056', '5991065', '6200942', '5107503']
# ['2020', '2019', '2018', '2017']
# 41번째 수행 중
# ANSS
# ['1445096', '1515892', '1293636', '1095250']
# ['2019', '2018', '2017']
# 42번째 수행 중
# ANTM
# ['117450000', '104213000', '92105000', '90039400']
# ['2019', '2018', '2017']
# 43번째 수행 중
# AON
# ['11089000', '11013000', '10770000', '9998000']
# ['2019', '2018', '2017']
# 44번째 수행 중
# AOS
# ['2992700', '2992700', '3187900', '2996700']
# ['2019', '2018', '2017']
# 45번째 수행 중
# APA
# ['4769000', '6315000', '7348000', '5887000']
# ['2019', '2018', '2017']
# 46번째 수행 중
# AAPL
# ['273857000', '274515000', '260174000', '265595000', '229234000']
# ['2020', '2019', '2018', '2017']
# 47번째 수행 중
# AMAT
# ['17202000', '17202000', '14608000', '17253000', '14537000']
# ['2020', '2019', '2018', '2017']
# 48번째 수행 중
# APTV
# ['14008000', '14357000', '14435000', '12884000']
# ['2019', '2018', '2017']
# 49번째 수행 중
# ADM
# ['64306000', '64355000', '64656000', '64341000', '60828000']
# ['2020', '2019', '2018', '2017']
# 50번째 수행 중
# ANET
# ['2410706', '2410706', '2151369', '1646186']
# ['2019', '2018', '2017']
# 크롤링 종료

# %%
df.to_csv('0129rs&p500_rate-50.csv')

# %%
df.head()
# Out:
#   ticker  ann_growth_rate  num_of_year recent_year
# 0    MMM         0.551855            4        2020
# 1    ABT         7.926117            3        2019
# 2   ABBV         8.580683            3        2019
# 3   ABMD        23.602235            4        2020
# 4    ACN         6.432967            4        2020

# %%
df_spx_ticker = list(df_spx.Symbol)

# %%
start = time.time()
df1 = make_ticker_rate_df(df_spx_ticker[:50])
df1.to_csv('0129rs&p500_rate-50.csv')
print("time :", time.time() - start)
# Out:
# MMM, 1번째 수행 중
# ABT, 2번째 수행 중
# ABBV, 3번째 수행 중
# ABMD, 4번째 수행 중
# ACN, 5번째 수행 중
# ATVI, 6번째 수행 중
# ADBE, 7번째 수행 중
# AMD, 8번째 수행 중
# AAP, 9번째 수행 중
# AES, 10번째 수행 중
# AFL, 11번째 수행 중
# A, 12번째 수행 중
# APD, 13번째 수행 중
# AKAM, 14번째 수행 중
# ALK, 15번째 수행 중
# ALB, 16번째 수행 중
# ARE, 17번째 수행 중
# ALXN, 18번째 수행 중
# ALGN, 19번째 수행 중
# ALLE, 20번째 수행 중
# LNT, 21번째 수행 중
# ALL, 22번째 수행 중
# GOOGL, 23번째 수행 중
# GOOG, 24번째 수행 중
# MO, 25번째 수행 중
# AMZN, 26번째 수행 중
# AMCR, 27번째 수행 중
# AEE, 28번째 수행 중
# AAL, 29번째 수행 중
# AEP, 30번째 수행 중
# AXP, 31번째 수행 중
# AIG, 32번째 수행 중
# AMT, 33번째 수행 중
# AWK, 34번째 수행 중
# AMP, 35번째 수행 중
# ABC, 36번째 수행 중
# AME, 37번째 수행 중
# AMGN, 38번째 수행 중
# APH, 39번째 수행 중
# ADI, 40번째 수행 중
# ANSS, 41번째 수행 중
# ANTM, 42번째 수행 중
# AON, 43번째 수행 중
# AOS, 44번째 수행 중
# APA, 45번째 수행 중
# AAPL, 46번째 수행 중
# AMAT, 47번째 수행 중
# APTV, 48번째 수행 중
# ADM, 49번째 수행 중
# ANET, 50번째 수행 중
# 크롤링 종료
# time : 3188.1009726524353

# %%
for i in range(50,len(df_spx_ticker),50):
    start = time.time()
    df1 = make_ticker_rate_df(df_spx_ticker[i:i+50])
    file_name = '0129rs&p500_rate-' + str(i+50) + '.csv'
    df1.to_csv(file_name)
    print("time :", time.time() - start)
# Out:
# AJG, 1번째 수행 중
# AIZ, 2번째 수행 중
# T, 3번째 수행 중
# ATO, 4번째 수행 중
# ADSK, 5번째 수행 중
# ADP, 6번째 수행 중
# AZO, 7번째 수행 중
# AVB, 8번째 수행 중
# AVY, 9번째 수행 중
# BKR, 10번째 수행 중
# BLL, 11번째 수행 중
# BAC, 12번째 수행 중
# BK, 13번째 수행 중
# BAX, 14번째 수행 중
# BDX, 15번째 수행 중
# BRKB, 16번째 수행 중
# BBY, 17번째 수행 중
# BIO, 18번째 수행 중
# BIIB, 19번째 수행 중
# BLK, 20번째 수행 중
# BA, 21번째 수행 중
# BKNG, 22번째 수행 중
# BWA, 23번째 수행 중
# BXP, 24번째 수행 중
# BSX, 25번째 수행 중
# BMY, 26번째 수행 중
# AVGO, 27번째 수행 중
# BR, 28번째 수행 중
# BFB, 29번째 수행 중
# CHRW, 30번째 수행 중
# COG, 31번째 수행 중
# CDNS, 32번째 수행 중
# CPB, 33번째 수행 중
# COF, 34번째 수행 중
# CAH, 35번째 수행 중
# KMX, 36번째 수행 중
# CCL, 37번째 수행 중
# CARR, 38번째 수행 중
# CTLT, 39번째 수행 중
# CAT, 40번째 수행 중
# CBOE, 41번째 수행 중
# CBRE, 42번째 수행 중
# CDW, 43번째 수행 중
# CE, 44번째 수행 중
# CNC, 45번째 수행 중
# CNP, 46번째 수행 중
# CERN, 47번째 수행 중
# CF, 48번째 수행 중
# SCHW, 49번째 수행 중
# CHTR, 50번째 수행 중
# 크롤링 종료
# time : 3636.4770741462708
# CVX, 1번째 수행 중
# CMG, 2번째 수행 중
# CB, 3번째 수행 중
# CHD, 4번째 수행 중
# CI, 5번째 수행 중
# CINF, 6번째 수행 중
# CTAS, 7번째 수행 중
# CSCO, 8번째 수행 중
# C, 9번째 수행 중
# CFG, 10번째 수행 중
# CTXS, 11번째 수행 중
# CLX, 12번째 수행 중
# CME, 13번째 수행 중
# CMS, 14번째 수행 중
# KO, 15번째 수행 중
# CTSH, 16번째 수행 중
# CL, 17번째 수행 중
# CMCSA, 18번째 수행 중
# CMA, 19번째 수행 중
# CAG, 20번째 수행 중
# COP, 21번째 수행 중
# ED, 22번째 수행 중
# STZ, 23번째 수행 중
# COO, 24번째 수행 중
# CPRT, 25번째 수행 중
# GLW, 26번째 수행 중
# CTVA, 27번째 수행 중
# COST, 28번째 수행 중
# CCI, 29번째 수행 중
# CSX, 30번째 수행 중
# CMI, 31번째 수행 중
# CVS, 32번째 수행 중
# DHI, 33번째 수행 중
# DHR, 34번째 수행 중
# DRI, 35번째 수행 중
# DVA, 36번째 수행 중
# DE, 37번째 수행 중
# DAL, 38번째 수행 중
# XRAY, 39번째 수행 중
# DVN, 40번째 수행 중
# DXCM, 41번째 수행 중
# FANG, 42번째 수행 중
# DLR, 43번째 수행 중
# DFS, 44번째 수행 중
# DISCA, 45번째 수행 중
# DISCK, 46번째 수행 중
# DISH, 47번째 수행 중
# DG, 48번째 수행 중
# DLTR, 49번째 수행 중
# D, 50번째 수행 중
# 크롤링 종료
# time : 3544.861013174057
# DPZ, 1번째 수행 중
# DOV, 2번째 수행 중
# DOW, 3번째 수행 중
# DTE, 4번째 수행 중
# DUK, 5번째 수행 중
# DRE, 6번째 수행 중
# DD, 7번째 수행 중
# DXC, 8번째 수행 중
# EMN, 9번째 수행 중
# ETN, 10번째 수행 중
# EBAY, 11번째 수행 중
# ECL, 12번째 수행 중
# EIX, 13번째 수행 중
# EW, 14번째 수행 중
# EA, 15번째 수행 중
# EMR, 16번째 수행 중
# ENPH, 17번째 수행 중
# ETR, 18번째 수행 중
# EOG, 19번째 수행 중
# EFX, 20번째 수행 중
# EQIX, 21번째 수행 중
# EQR, 22번째 수행 중
# ESS, 23번째 수행 중
# EL, 24번째 수행 중
# ETSY, 25번째 수행 중
# EVRG, 26번째 수행 중
# ES, 27번째 수행 중
# RE, 28번째 수행 중
# EXC, 29번째 수행 중
# EXPE, 30번째 수행 중
# EXPD, 31번째 수행 중
# EXR, 32번째 수행 중
# XOM, 33번째 수행 중
# FFIV, 34번째 수행 중
# FB, 35번째 수행 중
# FAST, 36번째 수행 중
# FRT, 37번째 수행 중
# FDX, 38번째 수행 중
# FIS, 39번째 수행 중
# FITB, 40번째 수행 중
# FE, 41번째 수행 중
# FRC, 42번째 수행 중
# FISV, 43번째 수행 중
# FLT, 44번째 수행 중
# FLIR, 45번째 수행 중
# FLS, 46번째 수행 중
# FMC, 47번째 수행 중
# F, 48번째 수행 중
# FTNT, 49번째 수행 중
# FTV, 50번째 수행 중
# 크롤링 종료
# time : 3839.0955674648285
# FBHS, 1번째 수행 중
# FOXA, 2번째 수행 중
# FOX, 3번째 수행 중
# BEN, 4번째 수행 중
# FCX, 5번째 수행 중
# GPS, 6번째 수행 중
# GRMN, 7번째 수행 중
# IT, 8번째 수행 중
# GD, 9번째 수행 중
# GE, 10번째 수행 중
# GIS, 11번째 수행 중
# GM, 12번째 수행 중
# GPC, 13번째 수행 중
# GILD, 14번째 수행 중
# GL, 15번째 수행 중
# GPN, 16번째 수행 중
# GS, 17번째 수행 중
# GWW, 18번째 수행 중
# HAL, 19번째 수행 중
# HBI, 20번째 수행 중
# HIG, 21번째 수행 중
# HAS, 22번째 수행 중
# HCA, 23번째 수행 중
# PEAK, 24번째 수행 중
# HSIC, 25번째 수행 중
# HSY, 26번째 수행 중
# HES, 27번째 수행 중
# HPE, 28번째 수행 중
# HLT, 29번째 수행 중
# HFC, 30번째 수행 중
# HOLX, 31번째 수행 중
# HD, 32번째 수행 중
# HON, 33번째 수행 중
# HRL, 34번째 수행 중
# HST, 35번째 수행 중
# HWM, 36번째 수행 중
# HPQ, 37번째 수행 중
# HUM, 38번째 수행 중
# HBAN, 39번째 수행 중
# HII, 40번째 수행 중
# IEX, 41번째 수행 중
# IDXX, 42번째 수행 중
# INFO, 43번째 수행 중
# ITW, 44번째 수행 중
# ILMN, 45번째 수행 중
# INCY, 46번째 수행 중
# IR, 47번째 수행 중
# INTC, 48번째 수행 중
# ICE, 49번째 수행 중
# IBM, 50번째 수행 중
# 크롤링 종료
# time : 3602.340026140213
# IP, 1번째 수행 중
# IPG, 2번째 수행 중
# IFF, 3번째 수행 중
# INTU, 4번째 수행 중
# ISRG, 5번째 수행 중
# IVZ, 6번째 수행 중
# IPGP, 7번째 수행 중
# IQV, 8번째 수행 중
# IRM, 9번째 수행 중
# JKHY, 10번째 수행 중
# J, 11번째 수행 중
# JBHT, 12번째 수행 중
# SJM, 13번째 수행 중
# JNJ, 14번째 수행 중
# JCI, 15번째 수행 중
# JPM, 16번째 수행 중
# JNPR, 17번째 수행 중
# KSU, 18번째 수행 중
# K, 19번째 수행 중
# KEY, 20번째 수행 중
# KEYS, 21번째 수행 중
# KMB, 22번째 수행 중
# KIM, 23번째 수행 중
# KMI, 24번째 수행 중
# KLAC, 25번째 수행 중
# KHC, 26번째 수행 중
# KR, 27번째 수행 중
# LB, 28번째 수행 중
# LHX, 29번째 수행 중
# LH, 30번째 수행 중
# LRCX, 31번째 수행 중
# LW, 32번째 수행 중
# LVS, 33번째 수행 중
# LEG, 34번째 수행 중
# LDOS, 35번째 수행 중
# LEN, 36번째 수행 중
# LLY, 37번째 수행 중
# LNC, 38번째 수행 중
# LIN, 39번째 수행 중
# LYV, 40번째 수행 중
# LKQ, 41번째 수행 중
# LMT, 42번째 수행 중
# L, 43번째 수행 중
# LOW, 44번째 수행 중
# LUMN, 45번째 수행 중
# LYB, 46번째 수행 중
# MTB, 47번째 수행 중
# MRO, 48번째 수행 중
# MPC, 49번째 수행 중
# MKTX, 50번째 수행 중
# 크롤링 종료
# time : 3507.5822248458862
# MAR, 1번째 수행 중
# MMC, 2번째 수행 중
# MLM, 3번째 수행 중
# MAS, 4번째 수행 중
# MA, 5번째 수행 중
# MKC, 6번째 수행 중
# MXIM, 7번째 수행 중
# MCD, 8번째 수행 중
# MCK, 9번째 수행 중
# MDT, 10번째 수행 중
# MRK, 11번째 수행 중
# MET, 12번째 수행 중
# MTD, 13번째 수행 중
# MGM, 14번째 수행 중
# MCHP, 15번째 수행 중
# MU, 16번째 수행 중
# MSFT, 17번째 수행 중
# MAA, 18번째 수행 중
# MHK, 19번째 수행 중
# TAP, 20번째 수행 중
# MDLZ, 21번째 수행 중
# MNST, 22번째 수행 중
# MCO, 23번째 수행 중
# MS, 24번째 수행 중
# MOS, 25번째 수행 중
# MSI, 26번째 수행 중
# MSCI, 27번째 수행 중
# NDAQ, 28번째 수행 중
# NTAP, 29번째 수행 중
# NFLX, 30번째 수행 중
# NWL, 31번째 수행 중
# NEM, 32번째 수행 중
# NWSA, 33번째 수행 중
# NWS, 34번째 수행 중
# NEE, 35번째 수행 중
# NLSN, 36번째 수행 중
# NKE, 37번째 수행 중
# NI, 38번째 수행 중
# NSC, 39번째 수행 중
# NTRS, 40번째 수행 중
# NOC, 41번째 수행 중
# NLOK, 42번째 수행 중
# NCLH, 43번째 수행 중
# NOV, 44번째 수행 중
# NRG, 45번째 수행 중
# NUE, 46번째 수행 중
# NVDA, 47번째 수행 중
# NVR, 48번째 수행 중
# ORLY, 49번째 수행 중
# OXY, 50번째 수행 중
# 크롤링 종료
# time : 3661.4533367156982
# ODFL, 1번째 수행 중
# OMC, 2번째 수행 중
# OKE, 3번째 수행 중
# ORCL, 4번째 수행 중
# OTIS, 5번째 수행 중
# PCAR, 6번째 수행 중
# PKG, 7번째 수행 중
# PH, 8번째 수행 중
# PAYX, 9번째 수행 중
# PAYC, 10번째 수행 중
# PYPL, 11번째 수행 중
# PNR, 12번째 수행 중
# PBCT, 13번째 수행 중
# PEP, 14번째 수행 중
# PKI, 15번째 수행 중
# PRGO, 16번째 수행 중
# PFE, 17번째 수행 중
# PM, 18번째 수행 중
# PSX, 19번째 수행 중
# PNW, 20번째 수행 중
# PXD, 21번째 수행 중
# PNC, 22번째 수행 중
# POOL, 23번째 수행 중
# PPG, 24번째 수행 중
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-51e2b29a172b> in <module>
#       1 for i in range(50,len(df_spx_ticker),50):
#       2     start = time.time()
# ----> 3     df1 = make_ticker_rate_df(df_spx_ticker[i:i+50])
#       4     file_name = '0129rs&p500_rate-' + str(i+50) + '.csv'
#       5     df1.to_csv(file_name)
#
# <ipython-input-3-a5ba7039c4ba> in make_ticker_rate_df(tickers)
#      29                         data = data.replace(',','')
#      30                         revenues.append(data)
# ---> 31                 time.sleep(5)
#      32         if revenues:
#      33             ticker_list.append(ticker)
#
# KeyboardInterrupt:

# %%
# 350 이후부터
for i in range(350,len(df_spx_ticker),50):
    start = time.time()
    if i >= 500:
        df1 = make_ticker_rate_df(df_spx_ticker[i:-1])
    else:
        df1 = make_ticker_rate_df(df_spx_ticker[i:i+50])
    file_name = '0129rs&p500_rate-' + str(i+50) + '.csv'
    df1.to_csv(file_name)
    print("time :", time.time() - start)
# Out:
# ODFL, 1번째 수행 중
# OMC, 2번째 수행 중
# OKE, 3번째 수행 중
# ORCL, 4번째 수행 중
# OTIS, 5번째 수행 중
# PCAR, 6번째 수행 중
# PKG, 7번째 수행 중
# PH, 8번째 수행 중
# PAYX, 9번째 수행 중
# PAYC, 10번째 수행 중
# PYPL, 11번째 수행 중
# PNR, 12번째 수행 중
# PBCT, 13번째 수행 중
# PEP, 14번째 수행 중
# PKI, 15번째 수행 중
# PRGO, 16번째 수행 중
# PFE, 17번째 수행 중
# PM, 18번째 수행 중
# PSX, 19번째 수행 중
# PNW, 20번째 수행 중
# PXD, 21번째 수행 중
# PNC, 22번째 수행 중
# POOL, 23번째 수행 중
# PPG, 24번째 수행 중
# PPL, 25번째 수행 중
# PFG, 26번째 수행 중
# PG, 27번째 수행 중
# PGR, 28번째 수행 중
# PLD, 29번째 수행 중
# PRU, 30번째 수행 중
# PEG, 31번째 수행 중
# PSA, 32번째 수행 중
# PHM, 33번째 수행 중
# PVH, 34번째 수행 중
# QRVO, 35번째 수행 중
# PWR, 36번째 수행 중
# QCOM, 37번째 수행 중
# DGX, 38번째 수행 중
# RL, 39번째 수행 중
# RJF, 40번째 수행 중
# RTX, 41번째 수행 중
# O, 42번째 수행 중
# REG, 43번째 수행 중
# REGN, 44번째 수행 중
# RF, 45번째 수행 중
# RSG, 46번째 수행 중
# RMD, 47번째 수행 중
# RHI, 48번째 수행 중
# ROK, 49번째 수행 중
# ROL, 50번째 수행 중
# 크롤링 종료
# time : 3359.3175961971283
# ROP, 1번째 수행 중
# ROST, 2번째 수행 중
# RCL, 3번째 수행 중
# SPGI, 4번째 수행 중
# CRM, 5번째 수행 중
# SBAC, 6번째 수행 중
# SLB, 7번째 수행 중
# STX, 8번째 수행 중
# SEE, 9번째 수행 중
# SRE, 10번째 수행 중
# NOW, 11번째 수행 중
# SHW, 12번째 수행 중
# SPG, 13번째 수행 중
# SWKS, 14번째 수행 중
# SLG, 15번째 수행 중
# SNA, 16번째 수행 중
# SO, 17번째 수행 중
# LUV, 18번째 수행 중
# SWK, 19번째 수행 중
# SBUX, 20번째 수행 중
# STT, 21번째 수행 중
# STE, 22번째 수행 중
# SYK, 23번째 수행 중
# SIVB, 24번째 수행 중
# SYF, 25번째 수행 중
# SNPS, 26번째 수행 중
# SYY, 27번째 수행 중
# TMUS, 28번째 수행 중
# TROW, 29번째 수행 중
# TTWO, 30번째 수행 중
# TPR, 31번째 수행 중
# TGT, 32번째 수행 중
# TEL, 33번째 수행 중
# FTI, 34번째 수행 중
# TDY, 35번째 수행 중
# TFX, 36번째 수행 중
# TER, 37번째 수행 중
# TSLA, 38번째 수행 중
# TXN, 39번째 수행 중
# TXT, 40번째 수행 중
# TMO, 41번째 수행 중
# TJX, 42번째 수행 중
# TSCO, 43번째 수행 중
# TT, 44번째 수행 중
# TDG, 45번째 수행 중
# TRV, 46번째 수행 중
# TRMB, 47번째 수행 중
# TFC, 48번째 수행 중
# TWTR, 49번째 수행 중
# TYL, 50번째 수행 중
# 크롤링 종료
# time : 3336.5158956050873
# TSN, 1번째 수행 중
# UDR, 2번째 수행 중
# ULTA, 3번째 수행 중
# USB, 4번째 수행 중
# UAA, 5번째 수행 중
# UA, 6번째 수행 중
# UNP, 7번째 수행 중
# UAL, 8번째 수행 중
# UNH, 9번째 수행 중
# UPS, 10번째 수행 중
# URI, 11번째 수행 중
# UHS, 12번째 수행 중
# UNM, 13번째 수행 중
# VLO, 14번째 수행 중
# VAR, 15번째 수행 중
# VTR, 16번째 수행 중
# VRSN, 17번째 수행 중
# VRSK, 18번째 수행 중
# VZ, 19번째 수행 중
# VRTX, 20번째 수행 중
# VFC, 21번째 수행 중
# VIAC, 22번째 수행 중
# VTRS, 23번째 수행 중
# V, 24번째 수행 중
# VNT, 25번째 수행 중
# VNO, 26번째 수행 중
# VMC, 27번째 수행 중
# WRB, 28번째 수행 중
# WAB, 29번째 수행 중
# WMT, 30번째 수행 중
# WBA, 31번째 수행 중
# DIS, 32번째 수행 중
# WM, 33번째 수행 중
# WAT, 34번째 수행 중
# WEC, 35번째 수행 중
# WFC, 36번째 수행 중
# WELL, 37번째 수행 중
# WST, 38번째 수행 중
# WDC, 39번째 수행 중
# WU, 40번째 수행 중
# WRK, 41번째 수행 중
# WY, 42번째 수행 중
# WHR, 43번째 수행 중
# WMB, 44번째 수행 중
# WLTW, 45번째 수행 중
# WYNN, 46번째 수행 중
# XEL, 47번째 수행 중
# XRX, 48번째 수행 중
# XLNX, 49번째 수행 중
# XYL, 50번째 수행 중
# 크롤링 종료
# time : 3395.709466934204
# YUM, 1번째 수행 중
# ZBRA, 2번째 수행 중
# ZBH, 3번째 수행 중
# ZION, 4번째 수행 중
# 크롤링 종료
# time : 288.7167160511017
